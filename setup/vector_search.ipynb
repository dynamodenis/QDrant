# %% [markdown]
# <a href="https://colab.research.google.com/github/dynamodenis/QDrant/blob/main/setup/vector_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qdrant-client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.9/389.9 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from qdrant_client import QdrantClient, models

# %%
from google.colab import userdata
client = QdrantClient(url=userdata.get("QDRANT_URL"), api_key=userdata.get("QDRANT_API_KEY"))

# %%
collection_name="denis_collection"

client.create_collection(
    collection_name=collection_name,
    vectors_config=models.VectorParams(size=4, # Dimensionality of the vectors
                                       distance=models.Distance.COSINE # Distance metric for similarity search
                                       )
)
# Out:
# True

# %%
# Retrieve and display the list of collections
collection = client.get_collection(collection_name)
collection

# %%
# Insert vectors into a collection
points = [
    models.PointStruct(
        id=1,
        vector=[0.1, 0.2, 0.3, 0.4],  # 4D vector,
        payload={"name": "Alice"}
    ),
    models.PointStruct(
        id=2,
        vector=[0.2, 0.3, 0.4, 0.5],
        payload={"name": "Bob"}
    )
]

client.upsert(
    collection_name=collection_name,
    points=points
)
# Out:
# UpdateResult(operation_id=1, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
# Retrive specific collection details
collection_info = client.get_collection(collection_name)
collection_info

# %%
# Run the similarity search using vector
query_vector = [0.08, 0.14, 0.33, 0.28]
search_results = client.query_points(
    collection_name=collection_name,
    query=query_vector,
    limit=2
)

search_results

# Expected output is alice and bob
# Out:
# QueryResponse(points=[ScoredPoint(id=1, version=1, score=0.97642946, payload={'name': 'Alice'}, vector=None, shard_key=None, order_value=None)])
